# %%
import pandas as pd
import seaborn as sns

news_articles = pd.read_csv('Op-Ed Sentiments - Sheet1 (24).csv') 
sympathy_scores = pd.read_csv('Sympathy Scores - Sheet1 (5).csv')
word_counts = pd.read_csv('Sheet 1-Updated_Op_Ed_Sentiments (1).csv')
# Out:
# /Users/chrislele/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
news_articles.head(15)
# Out:
#                                          Article Link  \
# 0   https://www.nytimes.com/2023/11/10/opinion/isr...
# 1   https://www.nytimes.com/2023/11/10/opinion/isr...
# 2   https://www.nytimes.com/2023/11/09/opinion/isr...
# 3   https://www.nytimes.com/2023/11/08/opinion/isr...
# 4   https://www.nytimes.com/2023/11/08/opinion/bid...
# 5   https://www.nytimes.com/2023/10/07/opinion/isr...
# 6   https://www.nytimes.com/2023/11/02/opinion/isr...
# 7   https://www.nytimes.com/2023/11/01/opinion/isr...
# 8   https://www.nytimes.com/2023/11/03/opinion/gaz...
# 9   https://www.nytimes.com/2023/11/03/opinion/isa...
# 10  https://www.nytimes.com/2023/11/03/opinion/isa...
# 11  https://www.nytimes.com/2023/11/04/opinion/sun...
# 12  https://www.nytimes.com/2023/11/04/opinion/sun...
# 13  https://www.nytimes.com/2023/11/05/opinion/isr...
# 14  https://www.nytimes.com/2023/10/27/opinion/isr...
#
#                                               Article  Polarity  Subjectivity  \
# 0   I landed in Israel and went straight to a fune...       NaN           NaN
# 1   Israeli military operations have created an un...       NaN           NaN
# 2   People warned me before I came to Tel Aviv a f...       NaN           NaN
# 3   My columns from Israel and the West Bank over ...       NaN           NaN
# 4   The Hamas terrorist attacks on Israel and Isra...       NaN           NaN
# 5   When I need the most accurate analysis about I...       NaN           NaN
# 6   On Oct. 25, Professor Nurit Peled-Elhanan, a l...       NaN           NaN
# 7   One reason I’m afraid that the worst is yet to...       NaN           NaN
# 8   Four weeks ago, Israel began its military camp...       NaN           NaN
# 9   Nothing is harder right now for many readers —...       NaN           NaN
# 10  I write these lines from Jerusalem, after spen...       NaN           NaN
# 11  When I was a law student backpacking through t...       NaN           NaN
# 12  Last week, the Anti-Defamation League and the ...       NaN           NaN
# 13  On Oct. 24 my brother and I went to the United...       NaN           NaN
# 14  Want the latest stories related to Israel and ...       NaN           NaN
#
#      Source        Date           Author
# 0   NYTimes  11/10/2023         Stephens
# 1   NYTimes  11/10/2023            Guest
# 2   NYTimes   11/9/2023         Friedman
# 3   NYTimes   11/8/2023          Kristof
# 4   NYTimes   11/8/2023           Edsall
# 5   NYTimes   10/7/2023         Friedman
# 6   NYTimes   11/2/2023            Sfard
# 7   NYTimes   11/1/2023          Kristof
# 8   NYTimes   11/3/2023  Editorial Board
# 9   NYTimes   11/3/2023        Kingsbury
# 10  NYTimes   11/3/2023           Herzog
# 11  NYTimes   11/4/2023          Kristof
# 12  NYTimes   11/4/2023         Goldberg
# 13  NYTimes   11/5/2023         Zeitchik
# 14  NYTimes  10/27/2023         Stephens

# %%
sympathy_scores.head()
# Out:
#                                         Article Link  SS (Human)  SS (GPT)  \
# 0  https://www.nytimes.com/2023/11/10/opinion/isr...       -0.80      -0.8
# 1  https://www.nytimes.com/2023/11/10/opinion/isr...         NaN       0.8
# 2  https://www.nytimes.com/2023/11/09/opinion/isr...       -0.50      -0.2
# 3  https://www.nytimes.com/2023/11/08/opinion/isr...         NaN       0.0
# 4  https://www.nytimes.com/2023/11/08/opinion/bid...       -0.35      -0.4
#
#    SS (Claude)  Final Score
# 0        -0.80        -0.80
# 1         0.70         0.75
# 2        -0.65        -0.50
# 3         0.20         0.10
# 4         0.00        -0.35

# %%
word_counts.head()
# Out:
#                                         Article Link  Stance (human)  \
# 0  https://www.nytimes.com/2023/11/10/opinion/isr...            -0.8
# 1  https://www.nytimes.com/2023/11/10/opinion/isr...             NaN
# 2  https://www.nytimes.com/2023/11/09/opinion/isr...             NaN
# 3  https://www.nytimes.com/2023/11/08/opinion/isr...             NaN
# 4  https://www.nytimes.com/2023/11/08/opinion/bid...             NaN
#
#    Stance (Chat)  Stance (Claude)  \
# 0           -0.8              NaN
# 1            NaN              NaN
# 2            NaN              NaN
# 3            NaN              NaN
# 4            NaN              NaN
#
#                                              Article  Polarity  Subjectivity  \
# 0  I landed in Israel and went straight to a fune...       NaN           NaN
# 1  Israeli military operations have created an un...       NaN           NaN
# 2  People warned me before I came to Tel Aviv a f...       NaN           NaN
# 3  My columns from Israel and the West Bank over ...       NaN           NaN
# 4  The Hamas terrorist attacks on Israel and Isra...       NaN           NaN
#
#    Words   Source   Date    Author
# 0   1275  NYTimes  11/10      2673
# 1   1444  NYTimes  11/10     Guest
# 2   2412  NYTimes   11/9  Friedman
# 3   1064  NYTimes   11/8   Kristof
# 4   2673  NYTimes   11/8    Edsall

# %%
from textblob import TextBlob

polarity = []
subjectivity = []

for index, row in news_articles.iterrows():
    if pd.notna(row['Article']):  # Assuming 'Article' is the column with text
        # Perform sentiment analysis
        analysis = TextBlob(row['Article'])
        # Append the results to the lists
        polarity.append(analysis.sentiment.polarity)
        subjectivity.append(analysis.sentiment.subjectivity)
    else:
        # Handle NaN value (e.g., append None or a default value)
        polarity.append(None)
        subjectivity.append(None)

# Add the lists as new columns to the DataFrame
news_articles['Polarity'] = polarity
news_articles['Subjectivity'] = subjectivity

# Save the updated DataFrame to a new CSV file
news_articles.to_csv('updated_news_articles.csv', index=False)

# %%
news_articles.head(10)
# Out:
#                                         Article Link  \
# 0  https://www.nytimes.com/2023/11/10/opinion/isr...
# 1  https://www.nytimes.com/2023/11/10/opinion/isr...
# 2  https://www.nytimes.com/2023/11/09/opinion/isr...
# 3  https://www.nytimes.com/2023/11/08/opinion/isr...
# 4  https://www.nytimes.com/2023/11/08/opinion/bid...
# 5  https://www.nytimes.com/2023/10/07/opinion/isr...
# 6  https://www.nytimes.com/2023/11/02/opinion/isr...
# 7  https://www.nytimes.com/2023/11/01/opinion/isr...
# 8  https://www.nytimes.com/2023/11/03/opinion/gaz...
# 9  https://www.nytimes.com/2023/11/03/opinion/isa...
#
#                                              Article  Polarity  Subjectivity  \
# 0  I landed in Israel and went straight to a fune...  0.035205      0.389367
# 1  Israeli military operations have created an un...  0.039283      0.404822
# 2  People warned me before I came to Tel Aviv a f...  0.074738      0.395492
# 3  My columns from Israel and the West Bank over ... -0.005551      0.435986
# 4  The Hamas terrorist attacks on Israel and Isra...  0.064684      0.426913
# 5  When I need the most accurate analysis about I...  0.030785      0.478788
# 6  On Oct. 25, Professor Nurit Peled-Elhanan, a l...  0.026491      0.420227
# 7  One reason I’m afraid that the worst is yet to... -0.015374      0.466326
# 8  Four weeks ago, Israel began its military camp...  0.051719      0.436402
# 9  Nothing is harder right now for many readers —...  0.041475      0.372837
#
#     Source        Date           Author
# 0  NYTimes  11/10/2023         Stephens
# 1  NYTimes  11/10/2023            Guest
# 2  NYTimes   11/9/2023         Friedman
# 3  NYTimes   11/8/2023          Kristof
# 4  NYTimes   11/8/2023           Edsall
# 5  NYTimes   10/7/2023         Friedman
# 6  NYTimes   11/2/2023            Sfard
# 7  NYTimes   11/1/2023          Kristof
# 8  NYTimes   11/3/2023  Editorial Board
# 9  NYTimes   11/3/2023        Kingsbury

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/chrislele/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
for index in range(1, 125):
    article = news_articles.loc[index, 'Article']
    if pd.notna(article):
        # Perform sentiment analysis
        analysis = TextBlob(article)
        polarity = analysis.sentiment.polarity
        subjectivity = analysis.sentiment.subjectivity

        # Assign values to the DataFrame
        news_articles.loc[index, 'Polarity'] = polarity
        news_articles.loc[index, 'Subjectivity'] = subjectivity

        # Print the results
        print(f'Article {index} - Polarity: {polarity}, Subjectivity: {subjectivity}')
    else:
        # Handle NaN value
        news_articles.loc[index, 'Polarity'] = None
        news_articles.loc[index, 'Subjectivity'] = None
        print(f'Article {index} - No content available for analysis.')
# Out:
# Article 1 - Polarity: 0.03928348028118671, Subjectivity: 0.40482197466142444
# Article 2 - Polarity: 0.07473835795846666, Subjectivity: 0.39549238503042855
# Article 3 - Polarity: -0.005551482567611586, Subjectivity: 0.43598601219568967
# Article 4 - Polarity: 0.06468385150203329, Subjectivity: 0.42691304276531544
# Article 5 - Polarity: 0.030784761585866547, Subjectivity: 0.4787882774070618
# Article 6 - Polarity: 0.026490909090909096, Subjectivity: 0.42022683982684006
# Article 7 - Polarity: -0.015373977873977873, Subjectivity: 0.4663258038258037
# Article 8 - Polarity: 0.05171940735321017, Subjectivity: 0.4364017437961099
# Article 9 - Polarity: 0.04147465437788018, Subjectivity: 0.372836661546339
# Article 10 - Polarity: 0.043849990589121056, Subjectivity: 0.46101909362778926
# Article 11 - Polarity: 0.0033461514844493607, Subjectivity: 0.4388122515782093
# Article 12 - Polarity: 0.0784525449298177, Subjectivity: 0.42217220910402725
# Article 13 - Polarity: 0.035373158587444296, Subjectivity: 0.44126072340358075
# Article 14 - Polarity: 0.04722749255952382, Subjectivity: 0.43508074824481097
# Article 15 - Polarity: 0.08428504485205515, Subjectivity: 0.4752555005132324
# Article 16 - Polarity: 0.01755588520674729, Subjectivity: 0.4900870776732847
# Article 17 - Polarity: 0.10796533575551434, Subjectivity: 0.41258168418882707
# Article 18 - Polarity: 0.06380772005772006, Subjectivity: 0.37995476745476753
# Article 19 - Polarity: 0.026603851010101008, Subjectivity: 0.44213194444444437
# Article 20 - Polarity: 0.07748335893497182, Subjectivity: 0.4582693292370711
# Article 21 - Polarity: 0.11120939245939244, Subjectivity: 0.38313862063862053
# Article 22 - Polarity: 0.022399385844507805, Subjectivity: 0.396621176926055
# Article 104 - Polarity: 0.02321708463949843, Subjectivity: 0.4221702866099418
# Article 105 - Polarity: 0.042434194158332085, Subjectivity: 0.5370913569189432
# Article 106 - Polarity: 0.04825428194993411, Subjectivity: 0.4656785243741765
# Article 107 - Polarity: 0.03478174603174602, Subjectivity: 0.36057539682539685
# Article 108 - Polarity: 0.0411965811965812, Subjectivity: 0.3725213675213675
# Article 109 - Polarity: 0.01523476523476523, Subjectivity: 0.3732067078220925
# Article 110 - Polarity: -0.020143343051506318, Subjectivity: 0.5180903790087462
# Article 111 - Polarity: 0.06337719298245614, Subjectivity: 0.47039473684210525
# Article 112 - Polarity: 0.09489828498449189, Subjectivity: 0.48150428753877017
# Article 113 - Polarity: 0.004543450376783712, Subjectivity: 0.3957591790925124
# Article 114 - Polarity: -0.015876217799294726, Subjectivity: 0.4164211856519549
# Article 115 - Polarity: 0.061322108124433714, Subjectivity: 0.4722893385684083
# Article 116 - Polarity: -0.013678535861634462, Subjectivity: 0.4249469036440866
# Article 117 - Polarity: 0.10935714285714286, Subjectivity: 0.4790059523809524
# Article 118 - Polarity: 0.02203222703222703, Subjectivity: 0.3737830687830689
# Article 119 - Polarity: 0.09191656828020466, Subjectivity: 0.48004329004329
# Article 120 - Polarity: 0.10132575757575757, Subjectivity: 0.4711742424242424
# Article 121 - Polarity: 0.014382573818057682, Subjectivity: 0.44060547875064004
# Article 122 - Polarity: 0.009317413005937605, Subjectivity: 0.565458630622565
# Article 123 - Polarity: 0.0704954954954955, Subjectivity: 0.345045045045045
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: 124 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/cr/5kdgskpn4_dbsjcgml40b3kr0000gn/T/ipykernel_97853/77657810.py in <module>
#       1 for index in range(1, 125):
# ----> 2     article = news_articles.loc[index, 'Article']
#       3     if pd.notna(article):
#       4         # Perform sentiment analysis
#       5         analysis = TextBlob(article)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     958             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     959             if self._is_scalar_access(key):
# --> 960                 return self.obj._get_value(*key, takeable=self._takeable)
#     961             return self._getitem_tuple(key)
#     962         else:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _get_value(self, index, col, takeable)
#    3620             #  results if our categories are integers that dont match our codes
#    3621             # IntervalIndex: IntervalTree has no get_loc
# -> 3622             row = self.index.get_loc(index)
#    3623             return series._values[row]
#    3624
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     385                     return self._range.index(new_key)
#     386                 except ValueError as err:
# --> 387                     raise KeyError(key) from err
#     388             self._check_indexing_error(key)
#     389             raise KeyError(key)
#
# KeyError: 124

# %%
news_articles = news_articles.drop_duplicates(subset=['Article Link'])
sympathy_scores = sympathy_scores.drop_duplicates(subset=['Article Link'])

# %%
merged_df = news_articles.merge(sympathy_scores[['Article Link', 'SS (Human)', 'SS (GPT)', 'SS (Claude)', 'Final Score']],
                               left_on='Article Link', right_on='Article Link', how='left')

# %%
finished_df = pd.merge(merged_df, word_counts[['Article', 'Words']], on='Article', how='left')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your dataframe is named 'merged_df'
# Calculate the correlation matrix
correlation_matrix = finished_df.corr()

# Visualize the correlation matrix using a heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
finished_df.reset_index(inplace=True)

# %%
finished_df['Date'] = pd.to_datetime(finished_df['Date'], format='%m/%d/%Y')  # adjust the format as per your data

# Sort the dataframe by 'Date'
finished_df.sort_values('Date', inplace=True)

# Plotting 'Final Score' over time
plt.figure(figsize=(12, 6))
plt.plot(finished_df['Date'], finished_df['Final Score'], marker='o')
plt.title('Change of Final Score Over Time')
plt.xlabel('Date')
plt.ylabel('Final Score')
plt.grid(True)
plt.show()

# %%
finished_df.head(10)
# Out:
#      index                                       Article Link  \
# 121    121  https://www.wsj.com/articles/fifty-years-since...
# 5        5  https://www.nytimes.com/2023/10/07/opinion/isr...
# 51      51  https://www.nytimes.com/2023/10/07/opinion/gaz...
# 71      71  https://www.cnn.com/2023/10/07/opinions/hamas-...
# 119    119  https://www.wsj.com/articles/this-is-an-irania...
# 120    120  https://www.wsj.com/articles/israel-faces-its-...
# 118    118  https://www.wsj.com/articles/israels-opportuni...
# 52      52  https://www.nytimes.com/2023/10/08/opinion/int...
# 53      53  https://www.nytimes.com/2023/10/09/opinion/isr...
# 117    117  https://www.wsj.com/articles/mitch-mcconnell-f...
#
#                                                Article  Polarity  \
# 121  Yom Kippur, the holiest day of the Jewish year...  0.070495
# 5    When I need the most accurate analysis about I...  0.030785
# 51   It’s easy to note the parallels between Hamas’... -0.014695
# 71   Millions of Israelis were jolted awake on Satu...  0.045020
# 119  As Jews celebrated a festive holiday on Saturd...  0.014383
# 120  Historical analogies are always tricky, but it...  0.009317
# 118  Hamas’s surprise attack is a humanitarian horr...  0.101326
# 52   Saturday will be remembered as one of the most...  0.068129
# 53   The brutal terrorist attack on Israel by Hamas... -0.028837
# 117  As hundreds of Iranian-backed terrorists storm...  0.091917
#
#      Subjectivity   Source       Date           Author  SS (Human)  SS (GPT)  \
# 121      0.345045      WSJ 2023-10-05            Ravid         NaN     -0.20
# 5        0.478788  NYTimes 2023-10-07         Friedman       -0.20     -0.70
# 51       0.396444  NYTimes 2023-10-07         Stephens         NaN     -0.20
# 71       0.417948      CNN 2023-10-08           Ghitis       -0.60     -0.75
# 119      0.440605      WSJ 2023-10-08      Kontorovich         NaN     -0.90
# 120      0.565459      WSJ 2023-10-08             Troy       -0.95     -0.90
# 118      0.471174      WSJ 2023-10-08            Pipes         NaN     -0.60
# 52       0.404965  NYTimes 2023-10-08             Meir         NaN     -0.50
# 53       0.475650  NYTimes 2023-10-09  Editorial Board         NaN     -0.70
# 117      0.480043      WSJ 2023-10-09         McConnel         NaN     -0.90
#
#      SS (Claude)  Final Score   Words
# 121         -0.1        -0.15   522.0
# 5           -0.2        -0.20  1977.0
# 51          -0.3        -0.25     NaN
# 71          -0.8        -0.60     NaN
# 119         -0.8        -0.85   917.0
# 120         -0.5        -0.95     NaN
# 118         -0.7        -0.65   573.0
# 52          -0.2        -0.35     NaN
# 53          -0.6        -0.65     NaN
# 117         -0.8        -0.85   679.0

# %%
finished_df['Date'] = pd.to_datetime(finished_df['Date'], format='%m/%d/%Y')
finished_df.set_index('Date', inplace=True)

# Group by week and calculate the mean 'Final Score'
weekly_scores = finished_df['Final Score'].resample('W').mean()

# Plotting weekly average 'Final Score'
plt.figure(figsize=(12, 6))
weekly_scores.plot(marker='o', linestyle='-')
plt.title('Weekly Average of Final Score')
plt.xlabel('Week')
plt.ylabel('Average Final Score')
plt.grid(True)
plt.show()

# %%
finished_df.reset_index(inplace=True)

# %%
finished_df['Date'] = pd.to_datetime(finished_df['Date'], format='%m/%d/%Y')
finished_df.set_index('Date', inplace=True)

# Filter dataframes by source
nytimes_df = finished_df[finished_df['Source'] == 'NYTimes']
cnn_df = finished_df[finished_df['Source'] == 'CNN']
wsj_df = finished_df[finished_df['Source'] == 'WSJ']

# Group by week and calculate mean for each source
weekly_nytimes = nytimes_df['Final Score'].resample('W').mean()
weekly_cnn = cnn_df['Final Score'].resample('W').mean()
weekly_wsj = wsj_df['Final Score'].resample('W').mean()

# Plotting weekly averages for each source
plt.figure(figsize=(12, 6))
weekly_nytimes.plot(marker='o', linestyle='-', label='NYTimes')
weekly_cnn.plot(marker='x', linestyle='-', label='CNN')
weekly_wsj.plot(marker='^', linestyle='-', label='WSJ')

plt.title('Weekly Average of Final Score by Source')
plt.xlabel('Week')
plt.ylabel('Average Final Score')
plt.legend()
plt.grid(True)
plt.show()

# %%
finished_df.reset_index(inplace=True)

# %%
finished_df.head(10)
# Out:
#         Date  index                                       Article Link  \
# 0 2023-10-05    121  https://www.wsj.com/articles/fifty-years-since...
# 1 2023-10-07      5  https://www.nytimes.com/2023/10/07/opinion/isr...
# 2 2023-10-07     51  https://www.nytimes.com/2023/10/07/opinion/gaz...
# 3 2023-10-08     71  https://www.cnn.com/2023/10/07/opinions/hamas-...
# 4 2023-10-08    119  https://www.wsj.com/articles/this-is-an-irania...
# 5 2023-10-08    120  https://www.wsj.com/articles/israel-faces-its-...
# 6 2023-10-08    118  https://www.wsj.com/articles/israels-opportuni...
# 7 2023-10-08     52  https://www.nytimes.com/2023/10/08/opinion/int...
# 8 2023-10-09     53  https://www.nytimes.com/2023/10/09/opinion/isr...
# 9 2023-10-09    117  https://www.wsj.com/articles/mitch-mcconnell-f...
#
#                                              Article  Polarity  Subjectivity  \
# 0  Yom Kippur, the holiest day of the Jewish year...  0.070495      0.345045
# 1  When I need the most accurate analysis about I...  0.030785      0.478788
# 2  It’s easy to note the parallels between Hamas’... -0.014695      0.396444
# 3  Millions of Israelis were jolted awake on Satu...  0.045020      0.417948
# 4  As Jews celebrated a festive holiday on Saturd...  0.014383      0.440605
# 5  Historical analogies are always tricky, but it...  0.009317      0.565459
# 6  Hamas’s surprise attack is a humanitarian horr...  0.101326      0.471174
# 7  Saturday will be remembered as one of the most...  0.068129      0.404965
# 8  The brutal terrorist attack on Israel by Hamas... -0.028837      0.475650
# 9  As hundreds of Iranian-backed terrorists storm...  0.091917      0.480043
#
#     Source           Author  SS (Human)  SS (GPT)  SS (Claude)  Final Score  \
# 0      WSJ            Ravid         NaN     -0.20         -0.1        -0.15
# 1  NYTimes         Friedman       -0.20     -0.70         -0.2        -0.20
# 2  NYTimes         Stephens         NaN     -0.20         -0.3        -0.25
# 3      CNN           Ghitis       -0.60     -0.75         -0.8        -0.60
# 4      WSJ      Kontorovich         NaN     -0.90         -0.8        -0.85
# 5      WSJ             Troy       -0.95     -0.90         -0.5        -0.95
# 6      WSJ            Pipes         NaN     -0.60         -0.7        -0.65
# 7  NYTimes             Meir         NaN     -0.50         -0.2        -0.35
# 8  NYTimes  Editorial Board         NaN     -0.70         -0.6        -0.65
# 9      WSJ         McConnel         NaN     -0.90         -0.8        -0.85
#
#     Words
# 0   522.0
# 1  1977.0
# 2     NaN
# 3     NaN
# 4   917.0
# 5     NaN
# 6   573.0
# 7     NaN
# 8     NaN
# 9   679.0

# %%
finished_df['Date'] = pd.to_datetime(finished_df['Date'], format='%m/%d')

# Filter dataframes by source and resample without setting 'Date' as index
nytimes_scores = finished_df[finished_df['Source'] == 'NYTimes'].resample('W', on='Date')['Polarity'].mean()
cnn_scores = finished_df[finished_df['Source'] == 'CNN'].resample('W', on='Date')['Polarity'].mean()
wsj_scores = finished_df[finished_df['Source'] == 'WSJ'].resample('W', on='Date')['Polarity'].mean()

# Plotting
plt.figure(figsize=(12, 6))
nytimes_scores.plot(marker='o', linestyle='-', label='NYTimes')
cnn_scores.plot(marker='x', linestyle='-', label='CNN')
wsj_scores.plot(marker='^', linestyle='-', label='WSJ')

plt.title('Weekly Average of Final Score by Source')
plt.xlabel('Week')
plt.ylabel('Average Final Score')
plt.legend()
plt.grid(True)
plt.show()

# %%
finished_df['Date'] = pd.to_datetime(finished_df['Date'], format='%m/%d')

# Filter dataframes by source and resample without setting 'Date' as index
nytimes_scores = finished_df[finished_df['Source'] == 'NYTimes'].resample('W', on='Date')['Subjectivity'].mean()
cnn_scores = finished_df[finished_df['Source'] == 'CNN'].resample('W', on='Date')['Subjectivity'].mean()
wsj_scores = finished_df[finished_df['Source'] == 'WSJ'].resample('W', on='Date')['Subjectivity'].mean()

# Plotting
plt.figure(figsize=(12, 6))
nytimes_scores.plot(marker='o', linestyle='-', label='NYTimes')
cnn_scores.plot(marker='x', linestyle='-', label='CNN')
wsj_scores.plot(marker='^', linestyle='-', label='WSJ')

plt.title('Weekly Average of Final Score by Source')
plt.xlabel('Week')
plt.ylabel('Average Final Score')
plt.legend()
plt.grid(True)
plt.show()

# %%
finished_df['Date'] = pd.to_datetime(finished_df['Date'], format='%m/%d')

# List of authors to analyze
top5_authors_to_analyze = ['Friedman', 'Stephens', 'Kristof', 'Ghitis', 'Goldberg', 'Editorial Board']  # replace with actual author names

# Plotting time series for each author
for author in top5_authors_to_analyze:
    author_df = finished_df[finished_df['Author'] == author]

    plt.figure(figsize=(12, 6))
    plt.plot(author_df['Date'], author_df['Final Score'], label='Final Score')
    plt.plot(author_df['Date'], author_df['Polarity'], label='Polarity')
    plt.plot(author_df['Date'], author_df['Subjectivity'], label='Subjectivity')

    plt.title(f'Time Series Analysis for {author}')
    plt.xlabel('Date')
    plt.ylabel('Scores')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
sns.scatterplot(data=finished_df, x='Final Score', y='Polarity')
plt.title('Scatter Plot of Final Score vs Polarity')
plt.show()

# Calculating Pearson Correlation Coefficient
pearson_corr, p_value = stats.pearsonr(finished_df['Final Score'].dropna(), finished_df['Polarity'].dropna())
print(f"Pearson Correlation Coefficient: {pearson_corr}, P-value: {p_value}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/cr/5kdgskpn4_dbsjcgml40b3kr0000gn/T/ipykernel_97853/543548344.py in <module>
#       4
#       5 # Calculating Pearson Correlation Coefficient
# ----> 6 pearson_corr, p_value = stats.pearsonr(finished_df['Final Score'].dropna(), finished_df['Polarity'].dropna())
#       7 print(f"Pearson Correlation Coefficient: {pearson_corr}, P-value: {p_value}")
#
# NameError: name 'stats' is not defined

# %%
import pandas as pd
import numpy as np

# Assuming your dataframe is named 'finished_df'
# Convert 'Date' to datetime and set as index (if not already done)
finished_df['Date'] = pd.to_datetime(finished_df['Date'], format='%m/%d')
finished_df.set_index('Date', inplace=True)

# Publications to analyze
publications = ['NYTimes', 'WSJ', 'CNN']

# Idea 1: Comparing Extremes
for publication in publications:
    pub_df = finished_df[finished_df['Source'] == publication]
    weekly_extremes = pub_df.resample('W')['Final Score'].agg(lambda x: x.nlargest(5).mean() - x.nsmallest(5).mean())

# Idea 2: Scoring System
def calculate_score(final_score):
    if -1.0 <= final_score <= -0.5 or 0.5 <= final_score <= 1.0:
        return 1
    return 0

# %%
import matplotlib.pyplot as plt

# Visualization for Idea 1: Comparing Extremes
plt.figure(figsize=(12, 6))
for publication in publications:
    pub_df = finished_df[finished_df['Source'] == publication]
    weekly_extremes = pub_df.resample('W')['Final Score'].agg(lambda x: x.nlargest(3).mean() - x.nsmallest(3).mean())
    weekly_extremes.plot(label=publication)

plt.title('Weekly Delta of Extremes for Each Publication')
plt.xlabel('Week')
plt.ylabel('Delta of Extremes')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt


# Assuming the 'Date' column is correctly set and 'finished_df' is your dataframe
# Define the scoring function
def calculate_score(final_score):
    if -1.0 <= final_score <= -0.5 or 0.5 <= final_score <= 1.0:
        return 1
    return 0

# Apply the scoring function
finished_df['Score'] = finished_df['Final Score'].apply(calculate_score)

# Reset index if 'Date' is set as index
finished_df.reset_index(inplace=True)

# Group by both 'Source' and 'Date', then calculate mean
weekly_scores = finished_df.groupby(['Source', pd.Grouper(freq='W', key='Date')])['Score'].mean()

# Visualization for Idea 2: Scoring System
plt.figure(figsize=(12, 6))
for publication in publications:
    # Retrieve scores for each publication
    pub_scores = weekly_scores[publication]
    plt.plot(pub_scores.index, pub_scores.values, label=publication)

plt.title('Weekly Average Score for Each Publication')
plt.xlabel('Week')
plt.ylabel('Average Score')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Create a boxplot for 'Final Score'
plt.figure(figsize=(10, 6))
sns.boxplot(x='Source', y='Final Score', data=finished_df)
plt.title('Boxplot of Final Score by Publication')
plt.show()

# Create a boxplot for 'Polarity'
plt.figure(figsize=(10, 6))
sns.boxplot(x='Source', y='Polarity', data=finished_df)
plt.title('Boxplot of Polarity by Publication')
plt.show()

# Assuming 'Bias' is a column in your dataframe
# Create a boxplot for 'Bias'
plt.figure(figsize=(10, 6))
sns.boxplot(x='Source', y='Subjectivity', data=finished_df)
plt.title('Boxplot of Subjectivity by Publication')
plt.show()

# %%
sns.scatterplot(data=finished_df, x='Final Score', y='Subjectivity')
plt.title('Scatter Plot of Final Score vs Polarity')
plt.show()

# Calculating Pearson Correlation Coefficient
pearson_corr, p_value = stats.pearsonr(finished_df['Final Score'].dropna(), finished_df['Subjectivity'].dropna())
print(f"Pearson Correlation Coefficient: {pearson_corr}, P-value: {p_value}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/cr/5kdgskpn4_dbsjcgml40b3kr0000gn/T/ipykernel_97853/2166827720.py in <module>
#       4
#       5 # Calculating Pearson Correlation Coefficient
# ----> 6 pearson_corr, p_value = stats.pearsonr(finished_df['Final Score'].dropna(), finished_df['Subjectivity'].dropna())
#       7 print(f"Pearson Correlation Coefficient: {pearson_corr}, P-value: {p_value}")
#
# NameError: name 'stats' is not defined

# %%
articles_per_publication = finished_df['Source'].value_counts()
print(articles_per_publication)
# Out:
# NYTimes    57
# WSJ        44
# CNN        21
# Name: Source, dtype: int64

# %%
authors_per_publication = finished_df['Author'].value_counts()
print(authors_per_publication)
# Out:
# Friedman          6
# Stephens          6
# Kristof           6
# Goldberg          5
# Ghitis            4
#                  ..
# Timoner           1
# Thomas Warrick    1
# Khan              1
# Wisse             1
# Guest             1
# Name: Author, Length: 86, dtype: int64

# %%
finished_df.reset_index(inplace=True)

# %%
# Convert your date column to a datetime type if it's not already
finished_df['Date'] = pd.to_datetime(finished_df['Date'])

# Set the date as the index
finished_df.set_index('Date', inplace=True)

# Resample data by week and calculate mean 'Final Score'
weekly_final_score = finished_df['Final Score'].resample('W').mean()  # Or median(), depending on your preference

# Plot the time series
weekly_final_score.plot(kind='line', title='Weekly Final Score')
# Out:
# <AxesSubplot:title={'center':'Weekly Final Score'}, xlabel='Date'>

# %%
missing_values = finished_df.isnull().sum()
print(missing_values)
# Out:
# level_0          0
# index            0
# Article Link     0
# Article          0
# Polarity         0
# Subjectivity     0
# Source           0
# Author           0
# SS (Human)      96
# SS (GPT)         1
# SS (Claude)      1
# Final Score      1
# Words           38
# Score            0
# dtype: int64

# %%
finished_df.head(10)
# Out:
#             level_0  index                                       Article Link  \
# Date
# 2023-10-05        0    121  https://www.wsj.com/articles/fifty-years-since...
# 2023-10-07        1      5  https://www.nytimes.com/2023/10/07/opinion/isr...
# 2023-10-07        2     51  https://www.nytimes.com/2023/10/07/opinion/gaz...
# 2023-10-08        3     71  https://www.cnn.com/2023/10/07/opinions/hamas-...
# 2023-10-08        4    119  https://www.wsj.com/articles/this-is-an-irania...
# 2023-10-08        5    120  https://www.wsj.com/articles/israel-faces-its-...
# 2023-10-08        6    118  https://www.wsj.com/articles/israels-opportuni...
# 2023-10-08        7     52  https://www.nytimes.com/2023/10/08/opinion/int...
# 2023-10-09        8     53  https://www.nytimes.com/2023/10/09/opinion/isr...
# 2023-10-09        9    117  https://www.wsj.com/articles/mitch-mcconnell-f...
#
#                                                       Article  Polarity  \
# Date
# 2023-10-05  Yom Kippur, the holiest day of the Jewish year...  0.070495
# 2023-10-07  When I need the most accurate analysis about I...  0.030785
# 2023-10-07  It’s easy to note the parallels between Hamas’... -0.014695
# 2023-10-08  Millions of Israelis were jolted awake on Satu...  0.045020
# 2023-10-08  As Jews celebrated a festive holiday on Saturd...  0.014383
# 2023-10-08  Historical analogies are always tricky, but it...  0.009317
# 2023-10-08  Hamas’s surprise attack is a humanitarian horr...  0.101326
# 2023-10-08  Saturday will be remembered as one of the most...  0.068129
# 2023-10-09  The brutal terrorist attack on Israel by Hamas... -0.028837
# 2023-10-09  As hundreds of Iranian-backed terrorists storm...  0.091917
#
#             Subjectivity   Source           Author  SS (Human)  SS (GPT)  \
# Date
# 2023-10-05      0.345045      WSJ            Ravid         NaN     -0.20
# 2023-10-07      0.478788  NYTimes         Friedman       -0.20     -0.70
# 2023-10-07      0.396444  NYTimes         Stephens         NaN     -0.20
# 2023-10-08      0.417948      CNN           Ghitis       -0.60     -0.75
# 2023-10-08      0.440605      WSJ      Kontorovich         NaN     -0.90
# 2023-10-08      0.565459      WSJ             Troy       -0.95     -0.90
# 2023-10-08      0.471174      WSJ            Pipes         NaN     -0.60
# 2023-10-08      0.404965  NYTimes             Meir         NaN     -0.50
# 2023-10-09      0.475650  NYTimes  Editorial Board         NaN     -0.70
# 2023-10-09      0.480043      WSJ         McConnel         NaN     -0.90
#
#             SS (Claude)  Final Score   Words  Score
# Date
# 2023-10-05         -0.1        -0.15   522.0      0
# 2023-10-07         -0.2        -0.20  1977.0      0
# 2023-10-07         -0.3        -0.25     NaN      0
# 2023-10-08         -0.8        -0.60     NaN      1
# 2023-10-08         -0.8        -0.85   917.0      1
# 2023-10-08         -0.5        -0.95     NaN      1
# 2023-10-08         -0.7        -0.65   573.0      1
# 2023-10-08         -0.2        -0.35     NaN      0
# 2023-10-09         -0.6        -0.65     NaN      1
# 2023-10-09         -0.8        -0.85   679.0      1

# %%
# Identifying rows with missing values in the 'Final' column
missing_final_rows = finished_df[finished_df['Final Score'].isnull()]

# Displaying the rows with missing values in 'Final'
print(missing_final_rows)
# Out:
#             level_0  index                                       Article Link  \
# Date
# 2023-10-10       15    114  m/articles/western-lecturing-and-israeli-restr...
#
#                                                       Article  Polarity  \
# Date
# 2023-10-10  “Too long have I lived among men who hate peac... -0.013679
#
#             Subjectivity Source   Author  SS (Human)  SS (GPT)  SS (Claude)  \
# Date
# 2023-10-10      0.424947    WSJ  Kaufman         NaN       NaN          NaN
#
#             Final Score  Words  Score
# Date
# 2023-10-10          NaN  921.0      0

# %%
print(finished_df['Final Score'].dtype)
# Out:
# float64

# %%
finished_df['Final Score'] = pd.to_numeric(finished_df['Final Score'], errors='coerce')

# %%
missing_final_rows = finished_df[finished_df['Final Score'].isnull()]
print(missing_final_rows)
# Out:
#             level_0  index                                       Article Link  \
# Date
# 2023-10-10       15    114  m/articles/western-lecturing-and-israeli-restr...
#
#                                                       Article  Polarity  \
# Date
# 2023-10-10  “Too long have I lived among men who hate peac... -0.013679
#
#             Subjectivity Source   Author  SS (Human)  SS (GPT)  SS (Claude)  \
# Date
# 2023-10-10      0.424947    WSJ  Kaufman         NaN       NaN          NaN
#
#             Final Score  Words  Score
# Date
# 2023-10-10          NaN  921.0      0

# %%
cleaned_df = finished_df.dropna(subset=['Final Score'])

# Check the shape of the DataFrame before and after to confirm the removal
print("Before removal:", cleaned_df.shape)
print("After removal:", cleaned_df.shape)
# Out:
# Before removal: (121, 14)
# After removal: (121, 14)

# %%
cleaned_df.head()
# Out:
#             level_0  index                                       Article Link  \
# Date
# 2023-10-05        0    121  https://www.wsj.com/articles/fifty-years-since...
# 2023-10-07        1      5  https://www.nytimes.com/2023/10/07/opinion/isr...
# 2023-10-07        2     51  https://www.nytimes.com/2023/10/07/opinion/gaz...
# 2023-10-08        3     71  https://www.cnn.com/2023/10/07/opinions/hamas-...
# 2023-10-08        4    119  https://www.wsj.com/articles/this-is-an-irania...
#
#                                                       Article  Polarity  \
# Date
# 2023-10-05  Yom Kippur, the holiest day of the Jewish year...  0.070495
# 2023-10-30       NaN
# 2023-10-30       NaN
# 2023-10-30     408.0
# 2023-10-30     738.0
# 2023-10-31    1157.0
# 2023-11-01       NaN
# 2023-11-01    1155.0
# 2023-11-01       NaN
# 2023-11-01       NaN
# 2023-11-01       NaN
# 2023-11-02     758.0
# 2023-11-02    1443.0
# 2023-11-02       NaN
# 2023-11-02     482.0
# 2023-11-03    1326.0
# 2023-11-03     958.0
# 2023-11-03     499.0
# 2023-11-03     992.0
# 2023-11-03     764.0
# 2023-11-03       NaN
# 2023-11-03     861.0
# 2023-11-04     943.0
# 2023-11-04    1675.0
# 2023-11-04       NaN
# 2023-11-05     675.0
# 2023-11-05    1247.0
# 2023-11-06     583.0
# 2023-11-07     729.0
# 2023-11-07    1379.0
# 2023-11-08    1064.0
# 2023-11-08    2673.0
# 2023-11-08    1044.0
# 2023-11-08     438.0
# 2023-11-09     727.0
# 2023-11-09     759.0
# 2023-11-09    2412.0
# 2023-11-09     768.0
# 2023-11-10     898.0
# 2023-11-10    1444.0
# 2023-11-10    1275.0

# %%
# Calculate the average word length for each publication
average_words_per_publication = cleaned_df.groupby('Source')['Words'].mean()

# Fill NaNs in 'Words' column with the average word length of the corresponding publication
cleaned_df['Words'] = cleaned_df.apply(
    lambda row: average_words_per_publication[row['Source']] if pd.isna(row['Words']) else row['Words'], 
    axis=1
)

# Display the first few rows to confirm the changes
cleaned_df.head()
# Out:
# /var/folders/cr/5kdgskpn4_dbsjcgml40b3kr0000gn/T/ipykernel_97853/2651022091.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['Words'] = cleaned_df.apply(
#             level_0  index                                       Article Link  \
# Date
# 2023-10-05        0    121  https://www.wsj.com/articles/fifty-years-since...
# 2023-10-07        1      5  https://www.nytimes.com/2023/10/07/opinion/isr...
# 2023-10-07        2     51  https://www.nytimes.com/2023/10/07/opinion/gaz...
# 2023-10-08        3     71  https://www.cnn.com/2023/10/07/opinions/hamas-...
# 2023-10-08        4    119  https://www.wsj.com/articles/this-is-an-irania...
#
#                                                       Article  Polarity  \
# Date
# 2023-10-05  Yom Kippur, the holiest day of the Jewish year...  0.070495
# 2023-10-07  When I need the most accurate analysis about I...  0.030785
# 2023-10-07  It’s easy to note the parallels between Hamas’... -0.014695
# 2023-10-08  Millions of Israelis were jolted awake on Satu...  0.045020
# 2023-10-08  As Jews celebrated a festive holiday on Saturd...  0.014383
#
#             Subjectivity   Source       Author  SS (Human)  SS (GPT)  \
# Date
# 2023-10-05      0.345045      WSJ        Ravid         NaN     -0.20
# 2023-10-07      0.478788  NYTimes     Friedman        -0.2     -0.70
# 2023-10-07      0.396444  NYTimes     Stephens         NaN     -0.20
# 2023-10-08      0.417948      CNN       Ghitis        -0.6     -0.75
# 2023-10-08      0.440605      WSJ  Kontorovich         NaN     -0.90
#
#             SS (Claude)  Final Score        Words  Score
# Date
# 2023-10-05         -0.1        -0.15   522.000000      0
# 2023-10-07         -0.2        -0.20  1977.000000      0
# 2023-10-07         -0.3        -0.25  1263.636364      0
# 2023-10-08         -0.8        -0.60   964.400000      1
# 2023-10-08         -0.8        -0.85   917.000000      1

# %%
cleaned_df.head(10)
# Out:
#             level_0  index                                       Article Link  \
# Date
# 2023-10-05        0    121  https://www.wsj.com/articles/fifty-years-since...
# 2023-10-07        1      5  https://www.nytimes.com/2023/10/07/opinion/isr...
# 2023-10-07        2     51  https://www.nytimes.com/2023/10/07/opinion/gaz...
# 2023-10-08        3     71  https://www.cnn.com/2023/10/07/opinions/hamas-...
# 2023-10-08        4    119  https://www.wsj.com/articles/this-is-an-irania...
# 2023-10-08        5    120  https://www.wsj.com/articles/israel-faces-its-...
# 2023-10-08        6    118  https://www.wsj.com/articles/israels-opportuni...
# 2023-10-08        7     52  https://www.nytimes.com/2023/10/08/opinion/int...
# 2023-10-09        8     53  https://www.nytimes.com/2023/10/09/opinion/isr...
# 2023-10-09        9    117  https://www.wsj.com/articles/mitch-mcconnell-f...
#
#                                                       Article  Polarity  \
# Date
# 2023-10-05  Yom Kippur, the holiest day of the Jewish year...  0.070495
# 2023-10-07  When I need the most accurate analysis about I...  0.030785
# 2023-10-07  It’s easy to note the parallels between Hamas’... -0.014695
# 2023-10-08  Millions of Israelis were jolted awake on Satu...  0.045020
# 2023-10-08  As Jews celebrated a festive holiday on Saturd...  0.014383
# 2023-10-08  Historical analogies are always tricky, but it...  0.009317
# 2023-10-08  Hamas’s surprise attack is a humanitarian horr...  0.101326
# 2023-10-08  Saturday will be remembered as one of the most...  0.068129
# 2023-10-09  The brutal terrorist attack on Israel by Hamas... -0.028837
# 2023-10-09  As hundreds of Iranian-backed terrorists storm...  0.091917
#
#             Subjectivity   Source           Author  SS (Human)  SS (GPT)  \
# Date
# 2023-10-05      0.345045      WSJ            Ravid         NaN     -0.20
# 2023-10-07      0.478788  NYTimes         Friedman       -0.20     -0.70
# 2023-10-07      0.396444  NYTimes         Stephens         NaN     -0.20
# 2023-10-08      0.417948      CNN           Ghitis       -0.60     -0.75
# 2023-10-08      0.440605      WSJ      Kontorovich         NaN     -0.90
# 2023-10-08      0.565459      WSJ             Troy       -0.95     -0.90
# 2023-10-08      0.471174      WSJ            Pipes         NaN     -0.60
# 2023-10-08      0.404965  NYTimes             Meir         NaN     -0.50
# 2023-10-09      0.475650  NYTimes  Editorial Board         NaN     -0.70
# 2023-10-09      0.480043      WSJ         McConnel         NaN     -0.90
#
#             SS (Claude)  Final Score        Words  Score
# Date
# 2023-10-05         -0.1        -0.15   522.000000      0
# 2023-10-07         -0.2        -0.20  1977.000000      0
# 2023-10-07         -0.3        -0.25  1263.636364      0
# 2023-10-08         -0.8        -0.60   964.400000      1
# 2023-10-08         -0.8        -0.85   917.000000      1
# 2023-10-08         -0.5        -0.95   717.350000      1
# 2023-10-08         -0.7        -0.65   573.000000      1
# 2023-10-08         -0.2        -0.35  1263.636364      0
# 2023-10-09         -0.6        -0.65  1263.636364      1
# 2023-10-09         -0.8        -0.85   679.000000      1

# %%
missing_values = cleaned_df.isnull().sum()
print(missing_values)
# Out:
# level_0          0
# index            0
# Article Link     0
# Article          0
# Polarity         0
# Subjectivity     0
# Source           0
# Author           0
# SS (Human)      95
# SS (GPT)         0
# SS (Claude)      0
# Final Score      0
# Words            0
# Score            0
# dtype: int64
